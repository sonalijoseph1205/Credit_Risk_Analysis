# %% [markdown]
# Importing the important modules pandas,seaborn,numpy,matplotlib nad warnings to filter warnings

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# Getting the datasets:
#
# inp0 = application.csv,
# inp1= column details,
# inp2= previous.csv

# %%
inp0 = pd.read_csv("application_data.csv")
inp1 = pd.read_csv("columns_description.csv", sep=",", encoding='cp1252')
inp2=pd.read_csv("previous_application.csv")

# %% [markdown]
# Understanding the data sets

# %%
inp0.describe()
# Out:
#           SK_ID_CURR         TARGET   CNT_CHILDREN  AMT_INCOME_TOTAL  \
# count  307511.000000  307511.000000  307511.000000      3.075110e+05
# mean   278180.518577       0.080729       0.417052      1.687979e+05
# std    102790.175348       0.272419       0.722121      2.371231e+05
# min    100002.000000       0.000000       0.000000      2.565000e+04
# 25%    189145.500000       0.000000       0.000000      1.125000e+05
# 50%    278202.000000       0.000000       0.000000      1.471500e+05
# 75%    367142.500000       0.000000       1.000000      2.025000e+05
# max    456255.000000       1.000000      19.000000      1.170000e+08
#
#          AMT_CREDIT    AMT_ANNUITY  AMT_GOODS_PRICE  \
# count  3.075110e+05  307499.000000     3.072330e+05
# mean   5.990260e+05   27108.573909     5.383962e+05
# std    4.024908e+05   14493.737315     3.694465e+05
# min    4.500000e+04    1615.500000     4.050000e+04
# 25%    2.700000e+05   16524.000000     2.385000e+05
# ...

# %%
inp0.shape
# Out:
# (307511, 122)

# %%
inp0.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 307511 entries, 0 to 307510
# Columns: 122 entries, SK_ID_CURR to AMT_REQ_CREDIT_BUREAU_YEAR
# dtypes: float64(65), int64(41), object(16)
# memory usage: 286.2+ MB

# %%
inp1.head(10)
# Out:
#    Unnamed: 0             Table                 Row  \
# 0           1  application_data          SK_ID_CURR
# 1           2  application_data              TARGET
# 2           5  application_data  NAME_CONTRACT_TYPE
# 3           6  application_data         CODE_GENDER
# 4           7  application_data        FLAG_OWN_CAR
# 5           8  application_data     FLAG_OWN_REALTY
# 6           9  application_data        CNT_CHILDREN
# 7          10  application_data    AMT_INCOME_TOTAL
# 8          11  application_data          AMT_CREDIT
# 9          12  application_data         AMT_ANNUITY
#
#                                          Description Special
# 0                           ID of loan in our sample     NaN
# 1  Target variable (1 - client with payment diffi...     NaN
# 2        Identification if loan is cash or revolving     NaN
# 3                               Gender of the client     NaN
# 4                      Flag if the client owns a car     NaN
# ...

# %%
inp1.shape
# Out:
# (160, 5)

# %%
inp2.describe()
# Out:
#          SK_ID_PREV    SK_ID_CURR   AMT_ANNUITY  AMT_APPLICATION  \
# count  1.670214e+06  1.670214e+06  1.297979e+06     1.670214e+06
# mean   1.923089e+06  2.783572e+05  1.595512e+04     1.752339e+05
# std    5.325980e+05  1.028148e+05  1.478214e+04     2.927798e+05
# min    1.000001e+06  1.000010e+05  0.000000e+00     0.000000e+00
# 25%    1.461857e+06  1.893290e+05  6.321780e+03     1.872000e+04
# 50%    1.923110e+06  2.787145e+05  1.125000e+04     7.104600e+04
# 75%    2.384280e+06  3.675140e+05  2.065842e+04     1.803600e+05
# max    2.845382e+06  4.562550e+05  4.180581e+05     6.905160e+06
#
#          AMT_CREDIT  AMT_DOWN_PAYMENT  AMT_GOODS_PRICE  \
# count  1.670213e+06      7.743700e+05     1.284699e+06
# mean   1.961140e+05      6.697402e+03     2.278473e+05
# std    3.185746e+05      2.092150e+04     3.153966e+05
# min    0.000000e+00     -9.000000e-01     0.000000e+00
# 25%    2.416050e+04      0.000000e+00     5.084100e+04
# ...

# %%
inp2.shape
# Out:
# (1670214, 37)

# %%
inp2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1670214 entries, 0 to 1670213
# Data columns (total 37 columns):
#  #   Column                       Non-Null Count    Dtype
# ---  ------                       --------------    -----
#  0   SK_ID_PREV                   1670214 non-null  int64
#  1   SK_ID_CURR                   1670214 non-null  int64
#  2   NAME_CONTRACT_TYPE           1670214 non-null  object
#  3   AMT_ANNUITY                  1297979 non-null  float64
#  4   AMT_APPLICATION              1670214 non-null  float64
#  5   AMT_CREDIT                   1670213 non-null  float64
#  6   AMT_DOWN_PAYMENT             774370 non-null   float64
#  7   AMT_GOODS_PRICE              1284699 non-null  float64
#  8   WEEKDAY_APPR_PROCESS_START   1670214 non-null  object
#  9   HOUR_APPR_PROCESS_START      1670214 non-null  int64
#  10  FLAG_LAST_APPL_PER_CONTRACT  1670214 non-null  object
#  11  NFLAG_LAST_APPL_IN_DAY       1670214 non-null  int64
# ...

# %%
inp2.head()
# Out:
#    SK_ID_PREV  SK_ID_CURR NAME_CONTRACT_TYPE  AMT_ANNUITY  AMT_APPLICATION  \
# 0     2030495      271877     Consumer loans     1730.430          17145.0
# 1     2802425      108129         Cash loans    25188.615         607500.0
# 2     2523466      122040         Cash loans    15060.735         112500.0
# 3     2819243      176158         Cash loans    47041.335         450000.0
# 4     1784265      202054         Cash loans    31924.395         337500.0
#
#    AMT_CREDIT  AMT_DOWN_PAYMENT  AMT_GOODS_PRICE WEEKDAY_APPR_PROCESS_START  \
# 0     17145.0               0.0          17145.0                   SATURDAY
# 1    679671.0               NaN         607500.0                   THURSDAY
# 2    136444.5               NaN         112500.0                    TUESDAY
# 3    470790.0               NaN         450000.0                     MONDAY
# 4    404055.0               NaN         337500.0                   THURSDAY
#
# ...

# %% [markdown]
# Data handling and cleaning

# %%
inp1.drop('Unnamed: 0',axis=1, inplace= True)

# %% [markdown]
# DAYS_BIRTH column

# %%
inp0.DAYS_BIRTH.head()
# Out:
# 0    -9461
# 1   -16765
# 2   -19046
# 3   -19005
# 4   -19932
# Name: DAYS_BIRTH, dtype: int64

# %% [markdown]
#  Age is given in days with a "-" in front of it so that will need cleaning:
#
#  a)Removing -
#
#  b)Converting Age in days to Age in years

# %%
inp0["Age"]=inp0["DAYS_BIRTH"].apply(lambda x: x//365 if x>0 else abs(x//365))

# %%
inp0.Age.describe()
# Out:
# count    307511.000000
# mean         44.433090
# std          11.954493
# min          21.000000
# 25%          35.000000
# 50%          44.000000
# 75%          54.000000
# max          70.000000
# Name: Age, dtype: float64

# %% [markdown]
# Binning age into groups

# %%
inp0["age_bins"]=pd.cut(x=inp0.Age,bins=[20,30,40,50,60,999],labels=["20-30","30-40","40-50","50-60","60+"])
inp0.head()
# Out:
#    SK_ID_CURR  TARGET NAME_CONTRACT_TYPE CODE_GENDER FLAG_OWN_CAR  \
# 0      100002       1         Cash loans           M            N
# 1      100003       0         Cash loans           F            N
# 2      100004       0    Revolving loans           M            Y
# 3      100006       0         Cash loans           F            N
# 4      100007       0         Cash loans           M            N
#
#   FLAG_OWN_REALTY  CNT_CHILDREN  AMT_INCOME_TOTAL  AMT_CREDIT  AMT_ANNUITY  \
# 0               Y             0          202500.0    406597.5      24700.5
# 1               N             0          270000.0   1293502.5      35698.5
# 2               Y             0           67500.0    135000.0       6750.0
# 3               Y             0          135000.0    312682.5      29686.5
# 4               Y             0          121500.0    513000.0      21865.5
#
#    ...  AMT_REQ_CREDIT_BUREAU_DAY AMT_REQ_CREDIT_BUREAU_WEEK  \
# ...

# %% [markdown]
# Handling the Education column

# %%
inp0.NAME_EDUCATION_TYPE.head(10)
# Out:
# 0     Secondary / secondary special
# 1                  Higher education
# 2     Secondary / secondary special
# 3     Secondary / secondary special
# 4     Secondary / secondary special
# 5     Secondary / secondary special
# 6                  Higher education
# 7                  Higher education
# 9     Secondary / secondary special
# 10                 Higher education
# Name: NAME_EDUCATION_TYPE, dtype: object

# %% [markdown]
# Removing the data after "/"

# %%
inp0["education"]=inp0.NAME_EDUCATION_TYPE.apply(lambda x : str(x.split("/")[0]))

# %%
inp0.education.describe()
# Out:
# count         307511
# unique             5
# top       Secondary
# freq          218391
# Name: education, dtype: object

# %%
inp0.education.head()
# Out:
# 0          Secondary
# 1    Higher education
# 2          Secondary
# 3          Secondary
# 4          Secondary
# Name: education, dtype: object

# %% [markdown]
# Checking the DAYS_EMPLOYED column:

# %%
inp0.DAYS_EMPLOYED.head()
# Out:
# 0    -637
# 1   -1188
# 2    -225
# 3   -3039
# 4   -3038
# Name: DAYS_EMPLOYED, dtype: int64

# %% [markdown]
# Removing "-"

# %%
inp0["DAYS_EMPLOYED"]=inp0.DAYS_EMPLOYED.apply(lambda x: abs(x))

# %%
inp0.DAYS_EMPLOYED.dtype
# Out:
# dtype('int64')

# %% [markdown]
# Checking for outliers in DAYS_EMPLOYED:

# %%
plt.boxplot(inp0.DAYS_EMPLOYED)
plt.show()

# %% [markdown]
# as these outliers might affect the analysis ,since we cannot guess how many days these people have been employed
# it would be better to drop these values

# %% [markdown]
# Identifying and removing the outliers

# %%
inp0.DAYS_EMPLOYED.sort_values(ascending=False)
# Out:
# 127705    365243
# 115938    365243
# 115800    365243
# 115794    365243
# 115793    365243
#            ...
# 161893         2
# 111965         2
# 246105         1
# 121625         0
# 23691          0
# Name: DAYS_EMPLOYED, Length: 307511, dtype: int64

# %%
inp0[inp0.DAYS_EMPLOYED>=35000]
# Out:
#         SK_ID_CURR  TARGET NAME_CONTRACT_TYPE CODE_GENDER FLAG_OWN_CAR  \
# 8           100011       0         Cash loans           F            N
# 11          100015       0         Cash loans           F            N
# 23          100027       0         Cash loans           F            N
# 38          100045       0         Cash loans           F            N
# 43          100050       0         Cash loans           F            N
# ...            ...     ...                ...         ...          ...
# 307469      456209       0         Cash loans           F            N
# 307483      456227       0         Cash loans           F            N
# 307487      456231       0         Cash loans           M            N
# 307505      456249       0         Cash loans           F            N
# 307507      456252       0         Cash loans           F            N
#
#        FLAG_OWN_REALTY  CNT_CHILDREN  AMT_INCOME_TOTAL  AMT_CREDIT  \
# ...

# %%
inp0=inp0[~(inp0.DAYS_EMPLOYED>=35000)]

# %%
inp0.DAYS_EMPLOYED.mean()
# Out:
# 2384.1693246132063

# %% [markdown]
# Making a column called "Months_employed" and converting days to months

# %%
inp0["Months_employed"]=inp0.DAYS_EMPLOYED.apply(lambda x: x//30)
inp0
# Out:
#         SK_ID_CURR  TARGET NAME_CONTRACT_TYPE CODE_GENDER FLAG_OWN_CAR  \
# 0           100002       1         Cash loans           M            N
# 1           100003       0         Cash loans           F            N
# 2           100004       0    Revolving loans           M            Y
# 3           100006       0         Cash loans           F            N
# 4           100007       0         Cash loans           M            N
# ...            ...     ...                ...         ...          ...
# 307504      456248       0         Cash loans           F            N
# 307506      456251       0         Cash loans           M            N
# 307508      456253       0         Cash loans           F            N
# 307509      456254       1         Cash loans           F            N
# 307510      456255       0         Cash loans           F            N
#
#        FLAG_OWN_REALTY  CNT_CHILDREN  AMT_INCOME_TOTAL  AMT_CREDIT  \
# ...

# %%
inp0.Months_employed.mean()
# Out:
# 78.98787563903751

# %% [markdown]
# Checking for outliers in Months_employed

# %%
plt.boxplot(inp0.Months_employed)
plt.show()

# %% [markdown]
# Binning Days employed into groups

# %%
inp0["Employed_length"]=pd.cut(x=inp0.Months_employed,bins=[0,12,60,120,180,240],labels=["fresher","2year+","10years+","15years+","20years+"])
inp0.head()
# Out:
#    SK_ID_CURR  TARGET NAME_CONTRACT_TYPE CODE_GENDER FLAG_OWN_CAR  \
# 0      100002       1         Cash loans           M            N
# 1      100003       0         Cash loans           F            N
# 2      100004       0    Revolving loans           M            Y
# 3      100006       0         Cash loans           F            N
# 4      100007       0         Cash loans           M            N
#
#   FLAG_OWN_REALTY  CNT_CHILDREN  AMT_INCOME_TOTAL  AMT_CREDIT  AMT_ANNUITY  \
# 0               Y             0          202500.0    406597.5      24700.5
# 1               N             0          270000.0   1293502.5      35698.5
# 2               Y             0           67500.0    135000.0       6750.0
# 3               Y             0          135000.0    312682.5      29686.5
# 4               Y             0          121500.0    513000.0      21865.5
#
#    ...  AMT_REQ_CREDIT_BUREAU_MON AMT_REQ_CREDIT_BUREAU_QRT  \
# ...

# %% [markdown]
# Comment: No outliers found

# %% [markdown]
# ANALYSING AMT_INCOME_TOTAL

# %%
inp0.AMT_INCOME_TOTAL.describe()
# Out:
# count    2.495990e+05
# mean     1.735082e+05
# std      1.052560e+05
# min      2.565000e+04
# 25%      1.125000e+05
# 50%      1.575000e+05
# 75%      2.025000e+05
# max      1.800009e+07
# Name: AMT_INCOME_TOTAL, dtype: float64

# %% [markdown]
# Checking for outliers in income

# %%
plt.boxplot(inp0.AMT_INCOME_TOTAL)
plt.show()

# %%
inp0.AMT_INCOME_TOTAL.sort_values(ascending=False)
# Out:
# 203693    18000090.0
# 131127     6750000.0
# 204564     4500000.0
# 187833     4500000.0
# 287463     4500000.0
#              ...
# 293194       27000.0
# 6401         27000.0
# 239654       27000.0
# 262748       26550.0
# 1678         25650.0
# Name: AMT_INCOME_TOTAL, Length: 249599, dtype: float64

# %%
inp0[inp0.AMT_INCOME_TOTAL>100000000]
# Out:
# Empty DataFrame
# ...

# %%
inp0[inp0.AMT_INCOME_TOTAL>10000000].head()
# Out:
#         SK_ID_CURR  TARGET NAME_CONTRACT_TYPE CODE_GENDER FLAG_OWN_CAR  \
# 203693      336147       0         Cash loans           M            Y
#
#        FLAG_OWN_REALTY  CNT_CHILDREN  AMT_INCOME_TOTAL  AMT_CREDIT  \
# 203693               Y             2        18000090.0    675000.0
#
#         AMT_ANNUITY  ...  AMT_REQ_CREDIT_BUREAU_MON AMT_REQ_CREDIT_BUREAU_QRT  \
# 203693      69295.5  ...                        NaN                       NaN
#
#        AMT_REQ_CREDIT_BUREAU_YEAR Age   education Months_employed  income_grp  \
# 203693                        NaN  44  Secondary              165          VH
#
#         age_bins  Credit_group  Employed_length
# 203693     40-50            VH         15years+
#
# [1 rows x 80 columns]

# %% [markdown]
# As there can be people with very high income, removing these will affect our analysis so we can do these two things:
#
# a) one income seems to be significantly higher than all else so we can remove that
#
# b)we can bin the rest of the income into groups

# %%
inp0.drop(index=12840,axis=0,inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\Users\SONALI~1\AppData\Local\Temp/ipykernel_12936/215898879.py in <module>
# ----> 1 inp0.drop(index=12840,axis=0,inplace=True)
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4904                 weight  1.0     0.8
#    4905         """
# -> 4906         return super().drop(
#    4907             labels=labels,
#    4908             axis=axis,
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
# ...

# %%
inp0.AMT_INCOME_TOTAL.describe()
# Out:
# count    2.495990e+05
# mean     1.735082e+05
# std      1.052560e+05
# min      2.565000e+04
# 25%      1.125000e+05
# 50%      1.575000e+05
# 75%      2.025000e+05
# max      1.800009e+07
# Name: AMT_INCOME_TOTAL, dtype: float64

# %%
inp0["income_grp"]=pd.cut(x=inp0.AMT_INCOME_TOTAL,bins=[0,100000,300000,600000,1000000,1500000,999999999],labels=["VL","L","AVG","AVG+","H","VH"])
inp0.head()
# Out:
#    SK_ID_CURR  TARGET NAME_CONTRACT_TYPE CODE_GENDER FLAG_OWN_CAR  \
# 0      100002       1         Cash loans           M            N
# 1      100003       0         Cash loans           F            N
# 2      100004       0    Revolving loans           M            Y
# 3      100006       0         Cash loans           F            N
# 4      100007       0         Cash loans           M            N
#
#   FLAG_OWN_REALTY  CNT_CHILDREN  AMT_INCOME_TOTAL  AMT_CREDIT  AMT_ANNUITY  \
# 0               Y             0          202500.0    406597.5      24700.5
# 1               N             0          270000.0   1293502.5      35698.5
# 2               Y             0           67500.0    135000.0       6750.0
# 3               Y             0          135000.0    312682.5      29686.5
# 4               Y             0          121500.0    513000.0      21865.5
#
#    ...  AMT_REQ_CREDIT_BUREAU_MON AMT_REQ_CREDIT_BUREAU_QRT  \
# ...

# %% [markdown]
# CHECKING FOR MISSING VALUES IN APPLICATION CSV

# %%
percent_missing_app = inp0.isnull().sum()*100/len(inp0) 
percent_missing_app.sort_values(ascending=False).head()
# Out:
# COMMONAREA_AVG              69.758384
# COMMONAREA_MEDI             69.758384
# COMMONAREA_MODE             69.758384
# NONLIVINGAPARTMENTS_MEDI    69.311403
# NONLIVINGAPARTMENTS_AVG     69.311403
# dtype: float64

# %% [markdown]
# Removing columns where missing values are more than 50%

# %%
inp0=inp0.drop(["COMMONAREA_MODE","COMMONAREA_MEDI","COMMONAREA_AVG","NONLIVINGAPARTMENTS_MODE","NONLIVINGAPARTMENTS_MEDI","NONLIVINGAPARTMENTS_AVG","FONDKAPREMONT_MODE","LIVINGAPARTMENTS_MEDI","LIVINGAPARTMENTS_AVG","LIVINGAPARTMENTS_MODE","FLOORSMIN_MEDI","FLOORSMIN_MODE","FLOORSMIN_AVG","OWN_CAR_AGE","YEARS_BUILD_AVG","YEARS_BUILD_MODE","YEARS_BUILD_MEDI","LANDAREA_AVG","LANDAREA_MEDI","LANDAREA_MODE","BASEMENTAREA_MODE","BASEMENTAREA_MEDI","BASEMENTAREA_AVG","NONLIVINGAREA_AVG","NONLIVINGAREA_MODE","NONLIVINGAREA_MEDI","ELEVATORS_AVG","ELEVATORS_MODE","ELEVATORS_MEDI","EXT_SOURCE_1","APARTMENTS_MODE","APARTMENTS_MEDI","APARTMENTS_AVG","WALLSMATERIAL_MODE","ENTRANCES_MODE","ENTRANCES_MEDI","ENTRANCES_AVG","HOUSETYPE_MODE","LIVINGAREA_MEDI","LIVINGAREA_MODE","LIVINGAREA_AVG","FLOORSMAX_MODE","FLOORSMAX_MEDI","FLOORSMAX_AVG","YEARS_BEGINEXPLUATATION_MEDI","YEARS_BEGINEXPLUATATION_MODE","YEARS_BEGINEXPLUATATION_AVG","TOTALAREA_MODE","EMERGENCYSTATE_MODE"],axis=1)

# %%
inp0.shape
# Out:
# (249599, 80)

# %%
inp0.dtypes.head(30)
# Out:
# SK_ID_CURR                      int64
# TARGET                          int64
# NAME_CONTRACT_TYPE             object
# CODE_GENDER                    object
# FLAG_OWN_CAR                   object
# FLAG_OWN_REALTY                object
# CNT_CHILDREN                    int64
# AMT_INCOME_TOTAL              float64
# AMT_CREDIT                    float64
# AMT_ANNUITY                   float64
# AMT_GOODS_PRICE               float64
# NAME_TYPE_SUITE                object
# NAME_INCOME_TYPE               object
# NAME_EDUCATION_TYPE            object
# NAME_FAMILY_STATUS             object
# NAME_HOUSING_TYPE              object
# REGION_POPULATION_RELATIVE    float64
# DAYS_BIRTH                      int64
# DAYS_EMPLOYED                   int64
# DAYS_REGISTRATION             float64
# DAYS_ID_PUBLISH                 int64
# FLAG_MOBIL                      int64
# FLAG_EMP_PHONE                  int64
# FLAG_WORK_PHONE                 int64
# FLAG_CONT_MOBILE                int64
# ...

# %% [markdown]
# ANALYSING OCCUPATION TYPE

# %%
inp0.OCCUPATION_TYPE.describe()
# Out:
# count       211117
# unique          18
# top       Laborers
# freq         55185
# Name: OCCUPATION_TYPE, dtype: object

# %% [markdown]
# Occupation should be a string

# %%
inp0.OCCUPATION_TYPE=inp0.OCCUPATION_TYPE.astype(str)

# %%
inp0.OCCUPATION_TYPE.value_counts()
# Out:
# Laborers                 55185
# nan                      41019
# Sales staff              32102
# Core staff               27570
# Managers                 21371
# Drivers                  18603
# High skill tech staff    11380
# Accountants               9813
# Medicine staff            8537
# Security staff            6721
# Cooking staff             5946
# Cleaning staff            4651
# Private service staff     2652
# Low-skill Laborers        2093
# Waiters/barmen staff      1348
# Secretaries               1305
# Realty agents              751
# HR staff                   563
# IT staff                   526
# Name: OCCUPATION_TYPE, dtype: int64

# %% [markdown]
# We can see that count of nan is high so we will replace that with 'Unknown'

# %%
inp0.loc[inp0['OCCUPATION_TYPE']=='nan','OCCUPATION_TYPE']='Unknown'

# %%
inp0.OCCUPATION_TYPE.value_counts()
# Out:
# Laborers                 55185
# Unknown                  41019
# Sales staff              32102
# Core staff               27570
# Managers                 21371
# Drivers                  18603
# High skill tech staff    11380
# Accountants               9813
# Medicine staff            8537
# Security staff            6721
# Cooking staff             5946
# Cleaning staff            4651
# Private service staff     2652
# Low-skill Laborers        2093
# Waiters/barmen staff      1348
# Secretaries               1305
# Realty agents              751
# HR staff                   563
# IT staff                   526
# Name: OCCUPATION_TYPE, dtype: int64

# %% [markdown]
# ANALYSING CODE_GENDER

# %%
inp0.CODE_GENDER.value_counts()
# Out:
# F      157176
# M       94956
# XNA         4
# Name: CODE_GENDER, dtype: int64

# %%
inp0.CODE_GENDER.mode()
# Out:
# 0    F
# dtype: object

# %%
#updating XNA with F

inp0.loc[inp0['CODE_GENDER']=='XNA','CODE_GENDER']='F'

# %%
inp0.CODE_GENDER.value_counts()
# Out:
# F    157180
# M     94956
# Name: CODE_GENDER, dtype: int64

# %% [markdown]
# ANALYSIS OF AMT_CREDIT

# %%
inp0.AMT_CREDIT.sort_values(ascending=False)
# Out:
# 120757    4050000.0
# 287732    4050000.0
# 133766    4050000.0
# 119681    4050000.0
# 17948     4050000.0
#             ...
# 146858      45000.0
# 271384      45000.0
# 61970       45000.0
# 45937       45000.0
# 221369      45000.0
# Name: AMT_CREDIT, Length: 252136, dtype: float64

# %%
inp0.AMT_CREDIT.median()
# Out:
# 521280.0

# %%
inp0["Credit_group"]=pd.cut(x=inp0.AMT_INCOME_TOTAL,bins=[0,50000,100000,600000,1000000,5000000,99999999999],labels=["VL","L","AVG","AVG+","H","VH"])
inp0.head()
# Out:
#    SK_ID_CURR  TARGET NAME_CONTRACT_TYPE CODE_GENDER FLAG_OWN_CAR  \
# 0      100002       1         Cash loans           M            N
# 1      100003       0         Cash loans           F            N
# 2      100004       0    Revolving loans           M            Y
# 3      100006       0         Cash loans           F            N
# 4      100007       0         Cash loans           M            N
#
#   FLAG_OWN_REALTY  CNT_CHILDREN  AMT_INCOME_TOTAL  AMT_CREDIT  AMT_ANNUITY  \
# 0               Y             0          202500.0    406597.5      24700.5
# 1               N             0          270000.0   1293502.5      35698.5
# 2               Y             0           67500.0    135000.0       6750.0
# 3               Y             0          135000.0    312682.5      29686.5
# 4               Y             0          121500.0    513000.0      21865.5
#
#    ...  AMT_REQ_CREDIT_BUREAU_WEEK AMT_REQ_CREDIT_BUREAU_MON  \
# ...

# %% [markdown]
# AMT_ANNUITY

# %%
plt.figure(figsize=(10,2))
sns.boxplot(inp0['AMT_ANNUITY'])
plt.show()

# %% [markdown]
# Excluding values outside 99 percentile for AMT_ANNUITY

# %%
inp0 = inp0[inp0['AMT_ANNUITY'] < np.nanpercentile(inp0['AMT_ANNUITY'], 99)]

# %%
plt.figure(figsize=(10,2))
sns.boxplot(inp0['AMT_ANNUITY'])
plt.show()

# %% [markdown]
# DIVIDING INP0 INTO TARGET=1 AND TARGET=0

# %%
target_1=inp0[inp0.TARGET==1]
target_0=inp0[inp0.TARGET==0]

# %% [markdown]
# Checking for the ratio of defaulters vs non defaulters:

# %%
sns.set(style="whitegrid")
plt.title("Defaulters vs Non defaulters")
sns.countplot(inp0.TARGET, hue=inp0.TARGET)
plt.show()

# %%
inp0.TARGET.value_counts()
# Out:
# 0    227855
# 1     21744
# Name: TARGET, dtype: int64

# %% [markdown]
# Out of more than 250000 applicants only 21834 are defaulters that is only 8% of the applicants.

# %% [markdown]
# UNIVARIATE ANALYSIS

# %% [markdown]
# AGE

# %%
plt.figure(figsize=(12,6))
plt.subplot(1,2,1)
plt.title("Age distribution for defaulters")
sns.kdeplot(target_0['Age'])
plt.subplot(1,2,2)
plt.title("Age distribution for non-defaulters")
sns.kdeplot(target_1['Age'])
plt.show()

# %% [markdown]
# Comment: We can see for defaulters Age rises peaks at 30 and then starts to fall

# %% [markdown]
# OCCUPATION_TYPE

# %%
plt.figure(figsize =[15,10])
sns.set(style="whitegrid")
plt.subplot(1,2,1)
plt.xticks(rotation = 90)
sns.histplot(target_1.OCCUPATION_TYPE,bins=40)
plt.title("Distribution of occupation type for target=1")
plt.subplot(1,2,2)
plt.xticks(rotation = 90)
sns.histplot(target_0.OCCUPATION_TYPE,bins=40)
plt.title("Distribution of occupation type for target=0")
plt.show()

# %% [markdown]
# Comment: This shows the most of the people with late payements are in the daily wage occupation i.e laborers
# a high number is also in low paying jobs like Sales staff and drivers

# %% [markdown]
# CODE_GENDER

# %%
plt.figure(figsize=[12,4])
plt.subplot(1,2,1)
sns.countplot(target_0['CODE_GENDER'])
plt.title("Gender Distribution in Non-defaulters")
plt.subplot(1,2,2)
sns.countplot(target_1['CODE_GENDER'])
plt.title("Gender Distribution in Defaulters")
plt.show()

# %% [markdown]
# INCOME GROUP

# %%
sns.set(style="whitegrid")
plt.figure(figsize=[12,4])
plt.subplot(1,2,1)
sns.histplot(data=target_0,x="income_grp")
plt.title("Income Distribution in Non-defaulters")
plt.subplot(1,2,2)
sns.histplot(data=target_1,x="income_grp")
plt.title("Income Distribution in Defaulters")
plt.show()

# %% [markdown]
# Commnet: The distribution of income group is similar for bith defaulters asw ell as non defaulters, most of the defaulters lie in the Low income group

# %% [markdown]
# NAME_INCOME_TYPE

# %%
plt.figure(figsize=[13,6])
plt.subplot(1,2,1)
sns.countplot(target_1['NAME_INCOME_TYPE'])
plt.xticks(rotation=90)
plt.title("Income Type in Defaulters")
plt.subplot(1,2,2)
sns.countplot(target_0['NAME_INCOME_TYPE'])
plt.xticks(rotation=90)
plt.title("Income Type in Non-Defaulters")
plt.show()

# %% [markdown]
# Comment: Most of the defaulters are in the working group

# %% [markdown]
# HOUSEING_TYPE

# %%
sns.set(style="whitegrid")
plt.figure(figsize=(8,5))
sns.countplot(inp0["NAME_HOUSING_TYPE"],hue=inp0["TARGET"])
plt.xticks(rotation=90)
plt.title("Hosuing type distribution")
plt.show()

# %% [markdown]
# Comment: Most of the defaulters live in House/apartment

# %% [markdown]
# AMT_ANNUITY

# %%
plt.figure(figsize=[13,6])
plt.subplot(1,2,1)
sns.kdeplot(target_1['AMT_ANNUITY'])
plt.xticks(rotation=90)
plt.title("Annuity distribution in Defaulters")
plt.subplot(1,2,2)
sns.kdeplot(target_0['AMT_ANNUITY'])
plt.xticks(rotation=90)
plt.title("Annuity distribution in Non-Defaulters")
plt.show()

# %% [markdown]
# Comment:  AMT_ANNUITY distribution is quite similar for both Defaulters and non-defaulters.

# %% [markdown]
# DIFFERENT VARIABLES VS DEFAULT RATE

# %% [markdown]
# AGE

# %%
plt.title("Distribution of defaulters across age groups")
plt.ylabel("Default rate")
inp0.groupby(['age_bins'])['TARGET'].mean().plot.bar()
plt.show()

# %% [markdown]
# Comment: As the Age increases the default rate decreases.

# %% [markdown]
# OCCUPATION

# %%
plt.figure(figsize=[10,8])
plt.title("Distribution of defaulters across Occupation types")
plt.ylabel("Default rate")
inp0.groupby(['OCCUPATION_TYPE'])['TARGET'].mean().plot.bar()
plt.show()

# %% [markdown]
# Comment: Default rate is highest for Low-skilled laborers

# %% [markdown]
# HOUSING_TYPE

# %%
plt.title("Distribution of defaulters across housing types")
plt.ylabel("Default rate")
inp0.groupby(['NAME_HOUSING_TYPE'])['TARGET'].mean().plot.bar()
plt.show()

# %% [markdown]
# Comment:
# Out of 200000+ applicants living is house/apartments only 8% of them are defaulters ,The people living in rented apartments and with their parents have the highest default rate i.e roughly 12% and 11% respectively

# %% [markdown]
# INCOME_TYPE

# %%
plt.title("Distribution of defaulters across income types")
plt.ylabel("Default rate")
inp0.groupby(['NAME_INCOME_TYPE'])['TARGET'].mean().plot.bar()
plt.show()

# %% [markdown]
# Comment: Mothers on maternity leave have teh highest default rate.

# %% [markdown]
# INCOME GROUP

# %%
plt.title("Distribution of defaulters across income groups")
plt.ylabel("Default rate")
inp0.groupby(['income_grp'])['TARGET'].mean().plot.bar()
plt.show()

# %% [markdown]
# Comment: Applicants with very low income have the highest default rate.

# %% [markdown]
# EDUCATION

# %%
plt.title("Distribution of defaulters across education levels")
plt.ylabel("Default rate")
inp0.groupby(['education'])['TARGET'].mean().plot.bar()
plt.show()

# %% [markdown]
# Comment : Applicants with Lower Secondary level education have the highest default rate.

# %% [markdown]
# GENDER

# %%
plt.title("Distribution of defaulters for Gender")
plt.ylabel("Default rate")
inp0.groupby(['CODE_GENDER'])['TARGET'].mean().plot.bar()
plt.show()

# %% [markdown]
# Comment: Men are more likely to default compared to women.

# %% [markdown]
# FLAG_OWN_CAR and FLAG_OWN_REALTY

# %%
plt.figure(figsize=[10,4])
plt.subplot(1,2,1)
plt.title("Distribution of defaulters who do and don't own Car")
plt.ylabel("Default rate")
inp0.groupby(['FLAG_OWN_CAR'])['TARGET'].mean().plot.bar()
plt.subplot(1,2,2)

plt.title("Distribution of defaulters who do and don't own Realty")
plt.ylabel("Default rate")
inp0.groupby(['FLAG_OWN_REALTY'])['TARGET'].mean().plot.bar()

plt.show()

# %%
inp0.FLAG_OWN_CAR.shape
# Out:
# (252136,)

# %%
inp0.FLAG_OWN_CAR.value_counts()
# Out:
# N    157718
# Y     94418
# Name: FLAG_OWN_CAR, dtype: int64

# %% [markdown]
# Comment: 62% applicants do not own car only about 37% applicants own car

# %%
inp0.FLAG_OWN_REALTY.shape
# Out:
# (252136,)

# %%
inp0.FLAG_OWN_REALTY.value_counts()
# Out:
# Y    171081
# N     81055
# Name: FLAG_OWN_REALTY, dtype: int64

# %% [markdown]
# Comment: About 67% applicants own realty

# %% [markdown]
# Comment: Applicants not owning realty and car and have a slightly higher default rate than the people who own realty and car

# %% [markdown]
# CONTARCT TYPE

# %%
plt.title("Distribution of defaulters for Contarct type")
plt.ylabel("Default rate")
inp0.groupby(['NAME_CONTRACT_TYPE'])['TARGET'].mean().plot.bar()
plt.show()

# %% [markdown]
# Comment: Applicants applying for cash loans have a higher cahnce of defaulting compared to people applying foe Revolving loan

# %% [markdown]
# CREDIT_GROUP

# %%
plt.figure(figsize=[15,4])
plt.subplot(1,2,1)
plt.title("Default rate for Credit amounts")
plt.ylabel("Default rate")
inp0.groupby(['Credit_group'])['TARGET'].mean().plot.bar()
plt.subplot(1,2,2)
plt.title("Distribution of Credit amounts for defaulters")
plt.ylabel("Count")
sns.countplot(target_1['Credit_group'])
plt.show()

# %% [markdown]
# Comment: Although most of the defaulters have an average credit amount the rate of default is highest for people with low credit and very low amount both being around 9%

# %% [markdown]
# DAYS EMPLOYED GROUP

# %%
plt.title("Distribution of defaulters for employment length")
plt.ylabel("Default rate")
inp0.groupby(['Employed_length'])['TARGET'].mean().plot.bar()
plt.show()

# %% [markdown]
# Comment: Freshers and people with 2-10 years of experience have the highest default rates.

# %% [markdown]
# ANALYISING REGION VARIABLES

# %%
fig=plt.subplots(figsize=(10, 10))

for i, j in enumerate(['REG_REGION_NOT_WORK_REGION','REG_CITY_NOT_LIVE_CITY', 'REG_CITY_NOT_WORK_CITY','REGION_RATING_CLIENT', 'REGION_RATING_CLIENT_W_CITY']):
    plt.subplot(5, 3, i+1, ylim=(0, 250000))
    plt.subplots_adjust(hspace = 1.0)
    sns.countplot(inp0[j], hue=inp0["TARGET"])
    plt.xticks(rotation=90)
    plt.tight_layout()

# %% [markdown]
# Comment: Default rate is highest when REG_REGION_NOT_WORK_REGION=0 that permanent address and working address are same.

# %% [markdown]
# EXT_SORCE_3

# %%
inp0[['EXT_SOURCE_3']].describe()
# Out:
#         EXT_SOURCE_3
# count  200342.000000
# mean        0.499786
# std         0.196050
# min         0.000527
# 25%         0.355639
# 50%         0.520898
# 75%         0.657784
# max         0.893976

# %%
sns.set(style="whitegrid")
plt.figure(figsize=(8,5))
sns.kdeplot(inp0["EXT_SOURCE_3"],hue=inp0["TARGET"])
plt.xticks(rotation=90)
plt.title("Hosuing type distribution")
plt.show()

# %% [markdown]
# Comment: EXT_SOURCE_3 has very different distribution for defaulters and non-defaulters

# %% [markdown]
# MULTIVARIATE ANALYSIS

# %% [markdown]
# Correlation among "Age","AMT_INCOME_TOTAL","AMT_ANNUITY","AMT_CREDIT"

# %%
sns.heatmap(inp0[["Age","AMT_INCOME_TOTAL","AMT_ANNUITY","AMT_CREDIT"]].corr(),annot=True,cmap="Greens")
plt.show()

# %% [markdown]
# Comment: There is a high correlation between annuity and credit.

# %% [markdown]
# INCOME GROUP vs MONTHS EMPLOYED

# %%
sns.barplot(data=inp0,x="income_grp",y="Months_employed",estimator=np.mean)
plt.show()

# %% [markdown]
#  Comment : Most of the people in the very high income range have been employed for an average of more than 80 months that is 3+ years.

# %% [markdown]
# Age vs Gender Vs Default Rate

# %%
resp=pd.pivot_table(data=inp0,index="CODE_GENDER",columns="age_bins",values="TARGET",fill_value=0)
plt.title("Age wise default rate of Males and Females")
sns.heatmap(resp,annot=True,cmap="RdYlGn")
plt.show()

# %% [markdown]
# Comment: Men in the age of 20-30 and 30-40 have a higher default rate and so do women in the age group 20-30

# %% [markdown]
# Age vs Education vs Default rate

# %%
res=pd.pivot_table(data=inp0,index="age_bins",columns="education",values="TARGET",fill_value=0)

# %%
res
# Out:
# education  Academic degree  Higher education  Incomplete higher  \
# age_bins
# 20-30               0.0000          0.067204           0.096080
# 30-40               0.0625          0.056164           0.085331
# 40-50               0.0000          0.050657           0.075269
# 50-60               0.0000          0.049643           0.063158
# 60+                 0.0000          0.034199           0.031250
#
# education  Lower secondary  Secondary
# age_bins
# 20-30             0.164345    0.142034
# 30-40             0.153285    0.113834
# 40-50             0.120075    0.084556
# 50-60             0.106509    0.069330
# 60+               0.098901    0.047779

# %%
sns.heatmap(res,annot=True,cmap="RdYlGn")
plt.show()

# %% [markdown]
# People with age 20-30 and Lower Secondary education have the highest default rate while people with Academic degree and Higher education have a lower default rate irrespective f their age group

# %% [markdown]
# Gender vs Annuity

# %%
sns.barplot(data=target_1,x="CODE_GENDER",y="AMT_ANNUITY")
plt.show()

# %% [markdown]
# Comment: Men have higher annuity amount compared to women

# %% [markdown]
# Gender vs Income

# %%
sns.barplot(data=target_1,x="CODE_GENDER",y="AMT_INCOME_TOTAL")
plt.show()

# %% [markdown]
# Comment: Men have higher income compared to women

# %% [markdown]
# Education vs Gender Vs Traget

# %%
res2=pd.pivot_table(data=inp0,index="CODE_GENDER",columns="education",values="TARGET",fill_value=0)
res2
# Out:
# education    Academic degree  Higher education  Incomplete higher  \
# CODE_GENDER
# F                       0.04          0.050550           0.082649
# M                       0.00          0.065438           0.093717
#
# education    Lower secondary  Secondary
# CODE_GENDER
# F                   0.128650    0.085944
# M                   0.146959    0.118248

# %%
sns.heatmap(res2,annot=True,cmap="RdYlGn")
plt.show()

# %% [markdown]
# Comment: This heat map shows that Male with Lower Secondary education have the highest default rate

# %% [markdown]
# Default rate in Contarct Type vs Credit Group

# %%
res3=pd.pivot_table(data=inp0,index="NAME_CONTRACT_TYPE",columns="Credit_group",values="TARGET",fill_value=0)
res3
# Out:
# Credit_group              VL         L       AVG      AVG+         H  VH
# NAME_CONTRACT_TYPE
# Cash loans          0.098199  0.099683  0.088973  0.059737  0.075758   0
# Revolving loans     0.072797  0.071964  0.052183  0.030651  0.000000   0

# %%
sns.heatmap(res3,annot=True,cmap="RdYlGn")
plt.show()

# %% [markdown]
# Comment: This heat map shows that applicants very low and low income group with cash loans have the highest default rates.

# %% [markdown]
# Default rate wrt Gender vs Employed length

# %%
res3=pd.pivot_table(data=inp0,index="CODE_GENDER",columns="Employed_length",values="TARGET",fill_value=0)
sns.heatmap(res3,annot=True,cmap="RdYlGn")
plt.show()

# %% [markdown]
# Conclusion: This shows that fresher males have the highest default rate followed closely by males with 2-10 years of experience

# %% [markdown]
# CONTRACT TYPE vs Education : Default distribution

# %%
res5=pd.pivot_table(data=inp0,index="NAME_CONTRACT_TYPE",columns="education",values="TARGET",fill_value=0)
sns.heatmap(res5,annot=True,cmap="RdYlGn")
plt.show()

# %% [markdown]
# Comment: we can see that people with Academic dgree applying for  a revolving loan have the lowest chance of defaulting
# while people with lower secondary education applying for cash loans have the highest chance

# %% [markdown]
# Occupation vs contract type vs default rate

# %%
inp0.groupby(['OCCUPATION_TYPE','NAME_CONTRACT_TYPE']).agg(default_rate=('TARGET','mean'))
inp0.reset_index()
plt.figure(figsize=[15,8])
plt.title("Occupation type vs Contract type vs Default rate")
plt.xticks(rotation=90)

sns.barplot(x='OCCUPATION_TYPE',
           y='TARGET',
           hue='NAME_CONTRACT_TYPE',
           data=inp0)
plt.xlabel("Occupation")
plt.ylabel("Default Rate")
plt.show()

# %% [markdown]
# CONCLUSION:we can see that low-skilled labbrours with Cash_loans have the highest default rate and
# IT staff with Revolving loan has the lowest default rate

# %% [markdown]
# Age vs Gender in Defaulters

# %%
inp0.groupby(['age_bins', 'CODE_GENDER']).agg(default_rate=('TARGET','mean'))
inp0.reset_index()
plt.title("Age vs Gender vs Default rate")

sns.barplot(x='age_bins',
           y='TARGET',
           hue='CODE_GENDER',
           data=inp0)
plt.xlabel("Age Group")
plt.ylabel("Default Rate")
plt.show()
#here we can see that 20-30 year age group has the highest default rate for bothe male and female

# %% [markdown]
# Comment: Men in the age group of 20-30 have the highest default rate followed by female in the age of 20-30
# and male in the age group of 30-40 years

# %% [markdown]
# Education vs Gender

# %%
inp0.groupby(['education', 'CODE_GENDER']).agg(default_rate=('TARGET','mean'))
inp0.reset_index()
plt.title("Education vs Gender vs Default rate")
plt.xticks(rotation=90)

sns.barplot(x='education',
           y='TARGET',
           hue='CODE_GENDER',
           data=inp0)
plt.xlabel("Education")
plt.ylabel("Default Rate")
plt.show()

# %% [markdown]
# conclusion:
#     default rates are highest for both male and female with lower secondary education followed by those with secondary education

# %% [markdown]
# Age vs Income vs default

# %%
inp0.groupby(['age_bins','income_grp']).agg(default_rate=('TARGET','mean'))
inp0.reset_index()
plt.figure(figsize=[15,8])
plt.title("Age vs Income vs Default rate")
plt.xticks(rotation=90)

sns.barplot(x='age_bins',
           y='TARGET',
           hue='income_grp',
           data=inp0)
plt.xlabel("Age")
plt.ylabel("Default Rate")
plt.show()

# %% [markdown]
# Conclusion: For all the income group as the age increases the default rate goes down

# %% [markdown]
# Goods Price Vs Credit

# %%
fig = plt.figure(figsize=[10,6])


plt.subplot(1,2,1)
plt.title("Non-defaulter")
sns.scatterplot(target_0['AMT_GOODS_PRICE'], target_0['AMT_CREDIT'])
plt.subplot(1,2,2)
plt.title("Defaulter")
sns.scatterplot(target_1['AMT_GOODS_PRICE'], target_1['AMT_CREDIT'])


plt.show()

# %% [markdown]
# Conclusion:
# 1)AMT_CREDIT and AMT_GOODS_PRICE have linear relation.
#
# 2) For lower range of AMT_CREDIT and AMT_GOODS_PRICE, amount of defaulters is less than that of non-defaulters

# %% [markdown]
# TOP 10 CORRELATION FOR DEFAULTERS

# %%
target_1_corr = target_1.corr()
round(target_1_corr, 2)

top_corr_list = target_1_corr.unstack()
top_corr_list.sort_values(ascending=False).drop_duplicates().head(10)
# Out:
# SK_ID_CURR                SK_ID_CURR                  1.000000
# DAYS_EMPLOYED             Months_employed             0.999989
# OBS_60_CNT_SOCIAL_CIRCLE  OBS_30_CNT_SOCIAL_CIRCLE    0.998288
# BASEMENTAREA_AVG          BASEMENTAREA_MEDI           0.998145
# YEARS_BUILD_MEDI          YEARS_BUILD_AVG             0.998144
# COMMONAREA_AVG            COMMONAREA_MEDI             0.998031
# LIVINGAPARTMENTS_MEDI     LIVINGAPARTMENTS_AVG        0.997920
# FLOORSMIN_MEDI            FLOORSMIN_AVG               0.997833
# LIVINGAREA_MEDI           LIVINGAREA_AVG              0.997806
# NONLIVINGAPARTMENTS_MEDI  NONLIVINGAPARTMENTS_AVG     0.997466
# dtype: float64

# %% [markdown]
# TOP 10 CORRELATION FOR NON DEFAULTERS

# %%
target_0_corr = target_0.corr()
round(target_0_corr, 2)

nondf_corr_list = target_0_corr.unstack()

# %%
nondf_corr_list.sort_values(ascending=False).drop_duplicates().head(10)
# Out:
# SK_ID_CURR                SK_ID_CURR                  1.000000
# Months_employed           DAYS_EMPLOYED               0.999993
# YEARS_BUILD_AVG           YEARS_BUILD_MEDI            0.998662
# OBS_30_CNT_SOCIAL_CIRCLE  OBS_60_CNT_SOCIAL_CIRCLE    0.998491
# FLOORSMIN_MEDI            FLOORSMIN_AVG               0.997240
# FLOORSMAX_MEDI            FLOORSMAX_AVG               0.997065
# ENTRANCES_MEDI            ENTRANCES_AVG               0.996883
# COMMONAREA_AVG            COMMONAREA_MEDI             0.996351
# ELEVATORS_MEDI            ELEVATORS_AVG               0.996176
# LIVINGAREA_AVG            LIVINGAREA_MEDI             0.995477
# dtype: float64
